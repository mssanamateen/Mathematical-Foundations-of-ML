# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
X,y = make_blobs(n_samples = 1000, n_features = 2, centers = 3, random_state= 42)

# %%
X.shape
# Out:
# (1000, 2)

# %%
plt.scatter(X[:,0], X[:,1])
plt.title('Data points')
# Out:
# Text(0.5, 1.0, 'Data points')

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest = train_test_split(X,y, test_size = 0.2, random_state = 420)

# %%
from sklearn.cluster import KMeans

# %%
# using manual Elbow method to select number of clusters for kmeans

wcss = []
for k in range(1, 10):
    # k-means++ is a faster version of the kmeans algo 
    # by selecting better-spaced initial centroids,
    # leading to faster convergence and more accurate,
    # stable clustering results.
    model = KMeans(n_clusters = k, init = 'k-means++')
    model.fit(x)
    wcss.append(model.inertia_)

# %%
wcss
# Out:
# [53572.54332884269,
#  30210.146979272973,
#  1584.8699545517943,
#  1396.7236499660696,
#  1279.3528837258216,
#  1049.011960619508,
#  919.555496597299,
#  835.8527742580477,
#  706.7094189429067]

# %%
plt.scatter(xtrain[:,0], xtrain[:,1])

# %%
plt.plot(range(1,10), wcss, marker = 'o')
plt.xticks(range(1,10))
plt.xlabel('Number of clusterz')
plt.ylabel("wcss values")
plt.show()

# %%
# we have elbow value of 3
# just trying both init options
# random - This option randomly selects the initial centroids from the data points
# k-means++ - selecting better-spaced initial centroids

model1 = KMeans(n_clusters = 3, init = 'random')
model2 = KMeans(n_clusters = 3, init = 'k-means++')

# %%
y_labels1 = model1.fit_predict(xtrain)
y_labels2 = model2.fit_predict(xtrain)

# %%
y_test_labels1 = model.predict(xtest)
y_test_labels2 = model.predict(xtest)

# %%
plt.scatter(xtrain[:,0], xtrain[:,1], c = y_labels1) 
plt.show()
plt.scatter(xtrain[:,0], xtrain[:,1], c = y_labels2)
plt.show()

# %%
plt.scatter(xtest[:,0],xtest[:,1], c = y_test_labels1)
plt.show()
plt.scatter(xtest[:,0],xtest[:,1], c = y_test_labels2)
plt.show()

# %% [markdown]
# # automatic method
#
# the KneeLocator function from knwwd library is used for detecting the optimal number of clusters for kmeans algorithm

# %%
from kneed import KneeLocator

# %%
knee = KneeLocator(range(1,10), wcss, curve = 'convex', direction = 'decreasing')
print("Elbow point (optimal k):", knee.knee)
# Out:
# Elbow point (optimal k): 3
