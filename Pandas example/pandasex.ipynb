# %%
import pandas as pd

# %% [markdown]
# **Pandas is a Python library. The name "Pandas" has a reference to both "Panel Data", and "Python Data Analysis" and was created by Wes McKinney in 2008.**
#
# 1.Pandas is used to analyze data.
#
# 2.Pandas is a Python library **used for working with data sets.**
#
# 3.It has functions for **analyzing, cleaning, exploring, and manipulating data.**

# %%
pd.__version__
# Out:
# '2.2.3'

# %% [markdown]
# ## Series
# - A Pandas Series is like a column in a table.
# - It is a one-dimensional array holding data of any type.

# %%
cars=pd.Series(["BMW","Toyota","Honda"])
cars
# Out:
# 0       BMW
# 1    Toyota
# 2     Honda
# dtype: object

# %% [markdown]
# ## Labels
# - labels are the identifiers used to access each element or value in the Series.
# - The label serves as the index that helps you identify and retrieve specific values from the Series.
# - If nothing else is specified, the values are labeled with their index number.
# - The first value has index 0, the second value has index 1, etc.

# %%
cust_index_cars=pd.Series(["BMW","Toyota","Honda"], index=["first","second","third"])
cust_index_cars
# Out:
# first        BMW
# second    Toyota
# third      Honda
# dtype: object

# %%
cust_index_cars["first"]
# Out:
# 'BMW'

# %%
cust_index_cars["second"]
# Out:
# 'Toyota'

# %%
cust_index_cars["third"]
# Out:
# 'Honda'

# %%
color_cars=pd.Series(["Red","Blue","White"])
color_cars
# Out:
# 0      Red
# 1     Blue
# 2    White
# dtype: object

# %% [markdown]
# ## DataFrame
# - row- axis=0
# - column- axis=1
# - A DataFrame is multidimensional or like a whole table

# %%
car_data=pd.DataFrame({"Car_make":cars,"color":color_cars})
car_data
# Out:
#   Car_make  color
# 0      BMW    Red
# 1   Toyota   Blue
# 2    Honda  White

# %% [markdown]
# ## read_csv
# -  loads  data into a DataFrame from a CSV (Comma-Separated Values) file

# %%
df1=pd.read_csv("./datasets/student_dataset.csv")

# %%
df1
# Out:
#     stud_id      stud_name    college_name            course  cgpa  \
# 0         1     John Smith  XYZ University  Computer Science   8.4
# 1         2    Alice Brown   ABC Institute   Mechanical Engg   7.1
# 2         3      Bob White     PQR College   Electrical Engg   8.8
# 3         4      Sarah Lee  XYZ University        Civil Engg   6.7
# 4         5      Tom Black   ABC Institute                IT   9.2
# 5         6    Emily Green     PQR College   Mechanical Engg   7.3
# 6         7      Mark Blue  XYZ University   Electrical Engg   8.5
# 7         8    Jenny Clark   ABC Institute  Computer Science   7.6
# 8         9     Kevin Gray     PQR College                IT   9.0
# 9        10    Laura White  XYZ University        Civil Engg   6.3
# 10       11   Rachel Adams  XYZ University  Computer Science   8.1
# 11       12    Peter Jones   ABC Institute   Mechanical Engg   6.9
# 12       13    Adam Carter     PQR College                IT   9.4
# ...

# %%
# !pip install --upgrade openpyxl

# %%
df2=pd.read_excel("./datasets/students_dataset.xlsx")

# %%
df2
# Out:
#     stud_id      stud_name    college_name            course  cgpa  \
# 0         1     John Smith  XYZ University  Computer Science   8.4
# 1         2    Alice Brown   ABC Institute   Mechanical Engg   7.1
# 2         3      Bob White     PQR College   Electrical Engg   8.8
# 3         4      Sarah Lee  XYZ University        Civil Engg   6.7
# 4         5      Tom Black   ABC Institute                IT   9.2
# 5         6    Emily Green     PQR College   Mechanical Engg   7.3
# 6         7      Mark Blue  XYZ University   Electrical Engg   8.5
# 7         8    Jenny Clark   ABC Institute  Computer Science   7.6
# 8         9     Kevin Gray     PQR College                IT   9.0
# 9        10    Laura White  XYZ University        Civil Engg   6.3
# 10       11   Rachel Adams  XYZ University  Computer Science   8.1
# 11       12    Peter Jones   ABC Institute   Mechanical Engg   6.9
# 12       13    Adam Carter     PQR College                IT   9.4
# ...

# %% [markdown]
# ## read_json

# %%
df3=pd.read_json("./datasets/student_d.json")

# %%
df3
# Out:
#     stud_id      stud_name    college_name            course  cgpa  \
# 0         1     John Smith  XYZ University  Computer Science   8.4
# 1         2    Alice Brown   ABC Institute   Mechanical Engg   7.1
# 2         3      Bob White     PQR College   Electrical Engg   8.8
# 3         4      Sarah Lee  XYZ University        Civil Engg   6.7
# 4         5      Tom Black   ABC Institute                IT   9.2
# 5         6    Emily Green     PQR College   Mechanical Engg   7.3
# 6         7      Mark Blue  XYZ University   Electrical Engg   8.5
# 7         8    Jenny Clark   ABC Institute  Computer Science   7.6
# 8         9     Kevin Gray     PQR College                IT   9.0
# 9        10    Laura White  XYZ University        Civil Engg   6.3
# 10       11   Rachel Adams  XYZ University  Computer Science   8.1
# 11       12    Peter Jones   ABC Institute   Mechanical Engg   6.9
# 12       13    Adam Carter     PQR College                IT   9.4
# ...

# %%
## csv file operations
#displays first 5 rows
df1.head()
# Out:
#    stud_id    stud_name    college_name            course  cgpa placed or not  \
# 0        1   John Smith  XYZ University  Computer Science   8.4           Yes
# 1        2  Alice Brown   ABC Institute   Mechanical Engg   7.1            No
# 2        3    Bob White     PQR College   Electrical Engg   8.8           Yes
# 3        4    Sarah Lee  XYZ University        Civil Engg   6.7            No
# 4        5    Tom Black   ABC Institute                IT   9.2           Yes
#
#   company_name
# 0     TechCorp
# 1          NaN
# 2  ElectroTech
# 3          NaN
# 4    CodeWorks

# %%
#displays last 5 rows
df1.tail()
# Out:
#     stud_id      stud_name    college_name            course  cgpa  \
# 55       56       Noah Lee  XYZ University        Civil Engg   6.5
# 56       57  Charlotte Kim   ABC Institute                IT   8.6
# 57       58    James Adams     PQR College   Electrical Engg   9.1
# 58       59    Emma Walker  XYZ University  Computer Science   7.8
# 59       60  Benjamin Gray   ABC Institute   Mechanical Engg   6.9
#
#    placed or not company_name
# 55            No          NaN
# 56           Yes      SoftNet
# 57           Yes  ElectroTech
# 58           Yes    CodeWorks
# 59            No            -

# %%
#gets the column names
df1.columns
# Out:
# Index(['stud_id', 'stud_name', 'college_name', 'course', 'cgpa',
#        'placed or not', 'company_name'],
#       dtype='object')

# %%
#check the data types
df1.dtypes
# Out:
# stud_id            int64
# stud_name         object
# college_name      object
# course            object
# cgpa             float64
# placed or not     object
# company_name      object
# dtype: object

# %%
#summary statistics
df1.describe()
# Out:
#          stud_id       cgpa
# count  60.000000  59.000000
# mean   30.500000   7.938983
# std    17.464249   0.967759
# min     1.000000   6.300000
# 25%    15.750000   7.000000
# 50%    30.500000   7.900000
# 75%    45.250000   8.800000
# max    60.000000   9.400000

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 59 entries, 0 to 59
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   stud_id       59 non-null     int64
#  1   stud_name     59 non-null     object
#  2   college_name  59 non-null     object
#  3   course        59 non-null     object
#  4   cgpa          58 non-null     float64
#  5   placed        59 non-null     object
#  6   company_name  59 non-null     object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 3.7+ KB

# %%
@label of the row
df1.loc[9]
# Out:
# stud_id                     10
# stud_name          Laura White
# college_name    XYZ University
# course              Civil Engg
# cgpa                       6.3
# placed                      No
# company_name                 -
# Name: 9, dtype: object

# %%
#integer based position
df1.iloc[9]
# Out:
# stud_id                       11
# stud_name           Rachel Adams
# college_name      XYZ University
# course          Computer Science
# cgpa                         8.1
# placed                       Yes
# company_name            TechCorp
# Name: 10, dtype: object

# %%
#gives the shape of the data (rows, columns)
df1.shape
# Out:
# (60, 7)

# %%
#check for null values
df1.isnull().sum()
# Out:
# stud_id          0
# stud_name        0
# college_name     0
# course           0
# cgpa             1
# placed or not    0
# company_name     6
# dtype: int64

# %% [markdown]
# ## Data Cleaning

# %%
#fill missing values
#df1['company_name'].fillna('NA',inplace=True)
#missing values in company column is filled with 'NA' and
#(inplace=True) this operation will modify original data frame rather than creating new data frame
df1.fillna({'company_name':'NA'},inplace=True)

# %%
df1.isnull().sum()
# Out:
# stud_id          0
# stud_name        0
# college_name     0
# course           0
# cgpa             1
# placed or not    0
# company_name     0
# dtype: int64

# %%
df1
# Out:
#     stud_id      stud_name    college_name            course  cgpa  \
# 0         1     John Smith  XYZ University  Computer Science   8.4
# 1         2    Alice Brown   ABC Institute   Mechanical Engg   7.1
# 2         3      Bob White     PQR College   Electrical Engg   8.8
# 3         4      Sarah Lee  XYZ University        Civil Engg   6.7
# 4         5      Tom Black   ABC Institute                IT   9.2
# 5         6    Emily Green     PQR College   Mechanical Engg   7.3
# 6         7      Mark Blue  XYZ University   Electrical Engg   8.5
# 7         8    Jenny Clark   ABC Institute  Computer Science   7.6
# 8         9     Kevin Gray     PQR College                IT   9.0
# 9        10    Laura White  XYZ University        Civil Engg   6.3
# 10       11   Rachel Adams  XYZ University  Computer Science   8.1
# 11       12    Peter Jones   ABC Institute   Mechanical Engg   6.9
# 12       13    Adam Carter     PQR College                IT   9.4
# ...

# %%
df1.columns
# Out:
# Index(['stud_id', 'stud_name', 'college_name', 'course', 'cgpa',
#        'placed or not', 'company_name'],
#       dtype='object')

# %%
df1.rename(columns={'placed or not':'placed'},inplace=True)

# %%
df1.columns
# Out:
# Index(['stud_id', 'stud_name', 'college_name', 'course', 'cgpa', 'placed',
#        'company_name'],
#       dtype='object')

# %% [markdown]
# ## Data Manipulation

# %%
#select columns
df1['stud_name']
# Out:
# 0        John Smith
# 1       Alice Brown
# 2         Bob White
# 3         Sarah Lee
# 4         Tom Black
# 5       Emily Green
# 6         Mark Blue
# 7       Jenny Clark
# 8        Kevin Gray
# 9       Laura White
# 10     Rachel Adams
# 11      Peter Jones
# 12      Adam Carter
# 13       Megan Hall
# 14     Olivia Black
# 15      David Green
# 16      Jessica Ray
# 17      Harry James
# 18      Sophia King
# 19       Liam Brown
# 20      Ethan Clark
# 21      Mia Roberts
# 22       Noah Davis
# 23       Ava Miller
# 24      Lucas Allen
# 25      Emma Walker
# 26      Mason Perez
# 27     Isabella Lee
# 28      Jacob Brown
# 29    Charlotte Kim
# 30     Olivia Green
# 31     Elijah Adams
# 32      Amelia King
# 33      Logan White
# 34     Harper Smith
# 35     James Taylor
# 36       Ella Brown
# 37     Henry Harris
# 38     Chloe Wilson
# 39     Benjamin Ray
# 40      Liam Harris
# 41     Sophia Davis
# 42      Logan White
# 43      Ava Johnson
# 44     Ethan Carter
# ...

# %%
#filtering rows
print(df1[df1['cgpa']>9.0])
# Out:
#     stud_id     stud_name    college_name           course  cgpa placed  \
# 4         5     Tom Black   ABC Institute               IT   9.2    Yes
# 12       13   Adam Carter     PQR College               IT   9.4    Yes
# 18       19   Sophia King   ABC Institute  Electrical Engg   9.1    Yes
# 22       23    Noah Davis   ABC Institute  Electrical Engg   9.2    Yes
# 32       33   Amelia King  XYZ University  Electrical Engg   9.3    Yes
# 38       39  Chloe Wilson  XYZ University               IT   9.1    Yes
# 42       43   Logan White     PQR College  Electrical Engg   9.3    Yes
# 53       54   Lucas White   ABC Institute  Electrical Engg   9.4    Yes
# 57       58   James Adams     PQR College  Electrical Engg   9.1    Yes
#
#    company_name
# 4     CodeWorks
# 12      SoftNet
# 18    PowerGrid
# 22  ElectroTech
# 32  ElectroTech
# 38      SoftNet
# 42  ElectroTech
# 53    PowerGrid
# 57  ElectroTech

# %%
df1['marks']=df1['stud_id']*5

# %%
df1.columns
# Out:
# Index(['stud_id', 'stud_name', 'college_name', 'course', 'cgpa', 'placed',
#        'company_name', 'marks'],
#       dtype='object')

# %%
df1.head()
# Out:
#    stud_id    stud_name    college_name            course  cgpa placed  \
# 0        1   John Smith  XYZ University  Computer Science   8.4    Yes
# 1        2  Alice Brown   ABC Institute   Mechanical Engg   7.1     No
# 2        3    Bob White     PQR College   Electrical Engg   8.8    Yes
# 3        4    Sarah Lee  XYZ University        Civil Engg   6.7     No
# 4        5    Tom Black   ABC Institute                IT   9.2    Yes
#
#   company_name  marks
# 0     TechCorp      5
# 1           NA     10
# 2  ElectroTech     15
# 3           NA     20
# 4    CodeWorks     25

# %%
#dropping column
df1.drop('marks',axis=1,inplace=True)

# %%
df1.columns
# Out:
# Index(['stud_id', 'stud_name', 'college_name', 'course', 'cgpa', 'placed',
#        'company_name'],
#       dtype='object')

# %% [markdown]
# ## Aggregation and Grouping

# %%
df1.dtypes
# Out:
# stud_id           int64
# stud_name        object
# college_name     object
# course           object
# cgpa            float64
# placed           object
# company_name     object
# dtype: object

# %%
#group by college name and calculate the mean of cgpa
avg_cgpa=df1.groupby('college_name')['cgpa'].mean()
avg_cgpa
# Out:
# college_name
# ABC Institute     7.810526
# PQR College       8.247368
# XYZ University    7.776190
# Name: cgpa, dtype: float64

# %%
#aggregation
df1['cgpa'].sum()
# Out:
# 468.40000000000003

# %%
df1['cgpa'].mean()
# Out:
# 7.938983050847458

# %%
#plot the highest cgpa based on the college
import matplotlib.pyplot as plt
highest_cgpa=df1.groupby('college_name')['cgpa'].max()
plt.figure(figsize=(8,6))
highest_cgpa.plot(kind='bar',color='skyblue')
plt.title('highest cgpa secured by college',fontsize=14)
plt.xlabel('College Name',fontsize=12)
plt.ylabel('highest cgpa',fontsize=12)

#show the plot
plt.xticks(rotation=45)#rotate xaxis labels
plt.show()

# %%
#pie chart
plt.figure(figsize=(7,7))
plt.pie(highest_cgpa,labels=highest_cgpa.index,autopct='%1.1f%%',startangle=140,colors=['skyblue','lightgreen','lightcoral'])
plt.title('percentage distribution of highest cgpa secured by college', fontsize=12)
plt.show()

# %%
#scatter plot
plt.figure(figsize=(8,6))
plt.scatter(df1['stud_id'],df1['cgpa'],color='skyblue', edgecolor='black')

plt.title('scatter plot of student id vs cgpa',fontsize=14)
plt.xlabel('student id',fontsize=12)
plt.ylabel('cgpa',fontsize=12)

plt.show()

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=60, step=1)

# %%
df1
# Out:
#     stud_id      stud_name    college_name            course  cgpa placed  \
# 0         1     John Smith  XYZ University  Computer Science   8.4    Yes
# 1         2    Alice Brown   ABC Institute   Mechanical Engg   7.1     No
# 2         3      Bob White     PQR College   Electrical Engg   8.8    Yes
# 3         4      Sarah Lee  XYZ University        Civil Engg   6.7     No
# 4         5      Tom Black   ABC Institute                IT   9.2    Yes
# 5         6    Emily Green     PQR College   Mechanical Engg   7.3    Yes
# 6         7      Mark Blue  XYZ University   Electrical Engg   8.5    Yes
# 7         8    Jenny Clark   ABC Institute  Computer Science   7.6     No
# 8         9     Kevin Gray     PQR College                IT   9.0    Yes
# 9        10    Laura White  XYZ University        Civil Engg   6.3     No
# 10       11   Rachel Adams  XYZ University  Computer Science   8.1    Yes
# 11       12    Peter Jones   ABC Institute   Mechanical Engg   6.9     No
# ...

# %%
df1.drop(index=[1],inplace=True)

# %%
df1
# Out:
#     stud_id      stud_name    college_name            course  cgpa placed  \
# 0         1     John Smith  XYZ University  Computer Science   8.4    Yes
# 2         3      Bob White     PQR College   Electrical Engg   8.8    Yes
# 3         4      Sarah Lee  XYZ University        Civil Engg   6.7     No
# 4         5      Tom Black   ABC Institute                IT   9.2    Yes
# 5         6    Emily Green     PQR College   Mechanical Engg   7.3    Yes
# 6         7      Mark Blue  XYZ University   Electrical Engg   8.5    Yes
# 7         8    Jenny Clark   ABC Institute  Computer Science   7.6     No
# 8         9     Kevin Gray     PQR College                IT   9.0    Yes
# 9        10    Laura White  XYZ University        Civil Engg   6.3     No
# 10       11   Rachel Adams  XYZ University  Computer Science   8.1    Yes
# 11       12    Peter Jones   ABC Institute   Mechanical Engg   6.9     No
# 12       13    Adam Carter     PQR College                IT   9.4    Yes
# ...
